# %% [markdown]
# # Data Visualization with Python Final Amt (BarChart)

# %%
## https://cloud.ibm.com/

# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# COURSERA Python Project: pillow, tesseract, and opencv                              #
# Week 3                                                                              #
#                                                                                     # 
# AUTHOR: Pablo Gonzalez Moreno                                                       #
# DATE: 21/1/2020                                                                     #
# VERSION: 1.0                                                                        #
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

url = 'https://cocl.us/datascience_survey_data'
df = pd.read_csv(url,  header=0 , names = ['Topic','Very interested','Somewhat interested','Not interested'])

#df.rename(columns={1: 'a'})
          
display(df)
# Out:
#                         Topic  Very interested  Somewhat interested  \
# 0   Big Data (Spark / Hadoop)             1332                  729
# 1  Data Analysis / Statistics             1688                  444
# 2             Data Journalism              429                 1081
# 3          Data Visualization             1340                  734
# 4               Deep Learning             1263                  770
# 5            Machine Learning             1629                  477
#
#    Not interested
# 0             127
# 1              60
# 2             610
# 3             102
# 4             136
# 5              74

# %%
#Use the artist layer of Matplotlib to replicate the bar chart below to visualize the percentage of the respondents' interest in the different data science topics surveyed.

# To create this bar chart, you can follow the following steps:
# 
# Sort the dataframe in descending order of Very interested.
df.sort_values(["Very interested"], ascending=False, axis=0, inplace=True)

# Convert the numbers into percentages of the total number of respondents. Recall that 2,233 respondents completed the survey. Round percentages to 2 decimal places.
df['Total'] = df.sum(axis=1)
df['Very interested'] = round(df['Very interested']/df['Total'],2)
df['Somewhat interested'] = round(df['Somewhat interested']/df['Total'],2)
df['Not interested'] = round(df['Not interested']/df['Total'],2)

df=df[['Topic','Very interested','Somewhat interested','Not interested']]
display(df)
# Out:
#                         Topic  Very interested  Somewhat interested  \
# 1  Data Analysis / Statistics             0.77                 0.20
# 5            Machine Learning             0.75                 0.22
# 3          Data Visualization             0.61                 0.34
# 0   Big Data (Spark / Hadoop)             0.61                 0.33
# 4               Deep Learning             0.58                 0.36
# 2             Data Journalism             0.20                 0.51
#
#    Not interested
# 1            0.03
# 5            0.03
# 3            0.05
# 0            0.06
# 4            0.06
# 2            0.29

# %%
# As for the chart:
df.plot(kind='bar',# bar width of 0.8,
         figsize=(20, 8), # use a figure size of (20, 8)
         color=['#5cb85c','#5bc0de','#d9534f']# use color #5cb85c for the Very interested bars, color #5bc0de for the Somewhat interested bars, and color #d9534f for the Not interested bars,    
        )

# display the labels on horizontal axis
plt.xticks(np.arange(6), df['Topic'])
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False

#remove labels on vertical axis
plt.yticks([])

#remove border on both axis
plt.box(False)

# use font size 14 for the bar labels, percentages, and legend,
plt.rc('font', size=14)          # controls default text sizes
plt.rc('axes', titlesize=14)     # fontsize of the axes title
plt.rc('axes', labelsize=14)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=14)    # fontsize of the tick labels
plt.rc('ytick', labelsize=14)    # fontsize of the tick labels
plt.rc('legend', fontsize=14)    # legend fontsize

# use font size 16 for the title, and,
plt.title("Percentage of Respondents' Interest in Data Science Areas", fontsize=16)


# display the percentages above the bars as shown above, and remove the left, top, and right borders.
#formatter = FuncFormatter(lambda y, pos: "%d%%" % (y))
#plt.yaxis.set_major_formatter(formatter)

  
plt.show()
